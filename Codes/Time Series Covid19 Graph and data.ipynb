# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\ASUS'

# %%
os.chdir('C:\\Users\\ASUS\\Desktop\\Xander\\ACETS')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_excel('C:\\Users\\ASUS\\Desktop\\Xander\\ACETS\\time_series_covid_19_confirmed.xlsx')
dataset.head(10)
# Out:
#                  Province/State       Country/Region       Lat        Long  \
# 0                           NaN          Afghanistan  33.93911   67.709953
# 1                           NaN              Albania  41.15330   20.168300
# 2                           NaN              Algeria  28.03390    1.659600
# 3                           NaN              Andorra  42.50630    1.521800
# 4                           NaN               Angola -11.20270   17.873900
# 5                           NaN  Antigua and Barbuda  17.06080  -61.796400
# 6                           NaN            Argentina -38.41610  -63.616700
# 7                           NaN              Armenia  40.06910   45.038200
# 8  Australian Capital Territory            Australia -35.47350  149.012400
# 9               New South Wales            Australia -33.86880  151.209300
#
#    2020-01-22 00:00:00  2020-01-23 00:00:00  2020-01-24 00:00:00  \
# 0                    0                    0                    0
# ...

# %%
a = dataset.head(20).reset_index()
plt.plot(a["Long"], label="Long")
plt.plot(a["Lat"], label="Lat")
plt.xticks(range(0,len(a["Long"])), rotation=90)
plt.xticks(range(0,len(a["Lat"])), rotation=90)
plt.legend()
plt.show()

# %%
dataset = pd.read_excel('C:\\Users\\ASUS\\Desktop\\Xander\\ACETS\\time_series_covid_19_confirmed_US.xlsx')
plt.plot(dataset["Long_"], label="Long")
plt.plot(dataset["Lat"], label="Lat")
plt.legend()
dataset.head(10)
# Out:
#         UID iso2 iso3  code3    FIPS    Admin2 Province_State Country_Region  \
# 0  84001001   US  USA    840  1001.0   Autauga        Alabama             US
# 1  84001003   US  USA    840  1003.0   Baldwin        Alabama             US
# 2  84001005   US  USA    840  1005.0   Barbour        Alabama             US
# 3  84001007   US  USA    840  1007.0      Bibb        Alabama             US
# 4  84001009   US  USA    840  1009.0    Blount        Alabama             US
# 5  84001011   US  USA    840  1011.0   Bullock        Alabama             US
# 6  84001013   US  USA    840  1013.0    Butler        Alabama             US
# 7  84001015   US  USA    840  1015.0   Calhoun        Alabama             US
# 8  84001017   US  USA    840  1017.0  Chambers        Alabama             US
# 9  84001019   US  USA    840  1019.0  Cherokee        Alabama             US
#
#          Lat      Long_  ... 2021-05-20 00:00:00  2021-05-21 00:00:00  \
# ...

# %%
dataset = pd.read_excel('C:\\Users\\ASUS\\Desktop\\Xander\\ACETS\\time_series_covid_19_deaths.xlsx')
dataset.head(10)
# Out:
#                  Province/State       Country/Region       Lat        Long  \
# 0                           NaN          Afghanistan  33.93911   67.709953
# 1                           NaN              Albania  41.15330   20.168300
# 2                           NaN              Algeria  28.03390    1.659600
# 3                           NaN              Andorra  42.50630    1.521800
# 4                           NaN               Angola -11.20270   17.873900
# 5                           NaN  Antigua and Barbuda  17.06080  -61.796400
# 6                           NaN            Argentina -38.41610  -63.616700
# 7                           NaN              Armenia  40.06910   45.038200
# 8  Australian Capital Territory            Australia -35.47350  149.012400
# 9               New South Wales            Australia -33.86880  151.209300
#
#    2020-01-22 00:00:00  2020-01-23 00:00:00  2020-01-24 00:00:00  \
# 0                    0                    0                    0
# ...

# %%
a = dataset.head(20).reset_index()

plt.plot(a["Long"], label="Long")
plt.plot(a["Lat"], label="Lat")
plt.xticks(range(0,len(a["Long"])), rotation=90)
plt.xticks(range(0,len(a["Lat"])), rotation=90)
plt.legend()
plt.show()

# %%
dataset = pd.read_excel('C:\\Users\\ASUS\\Desktop\\Xander\\ACETS\\time_series_covid_19_deaths_US.xlsx')

plt.plot(dataset["Long_"], label="Long")
plt.plot(dataset["Lat"], label="Lat")
plt.legend()
dataset.head(10)
# Out:
#         UID iso2 iso3  code3    FIPS    Admin2 Province_State Country_Region  \
# 0  84001001   US  USA    840  1001.0   Autauga        Alabama             US
# 1  84001003   US  USA    840  1003.0   Baldwin        Alabama             US
# 2  84001005   US  USA    840  1005.0   Barbour        Alabama             US
# 3  84001007   US  USA    840  1007.0      Bibb        Alabama             US
# 4  84001009   US  USA    840  1009.0    Blount        Alabama             US
# 5  84001011   US  USA    840  1011.0   Bullock        Alabama             US
# 6  84001013   US  USA    840  1013.0    Butler        Alabama             US
# 7  84001015   US  USA    840  1015.0   Calhoun        Alabama             US
# 8  84001017   US  USA    840  1017.0  Chambers        Alabama             US
# 9  84001019   US  USA    840  1019.0  Cherokee        Alabama             US
#
#          Lat      Long_  ... 2021-05-20 00:00:00  2021-05-21 00:00:00  \
# ...
